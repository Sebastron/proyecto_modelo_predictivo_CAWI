# %% [markdown]
# # Instalación de dependencias

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.7.0)

# %% [markdown]
# # Librerias y/o dependencias a utilizar

# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras import backend as K
from keras.callbacks import TensorBoard,EarlyStopping,ModelCheckpoint,ReduceLROnPlateau
import datetime
from keras.utils import np_utils
import seaborn as sns

# %% [markdown]
# # Lectura del dataset de prueba

# %%
from google.colab import drive
drive.mount('/content/drive/')
path = '/content/drive/My Drive/Trabajo de título/TT2/Red neuronal/'
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Multi pruebas

# %%
def red_neuronal_dos_salidas(df, optimizador, f_perdida, capas, epocas, tamano):
    #Particion de datos de entrenamiento y prueba
    Train = df[(df['Mes_envio']<0.5)]
    X_train = Train.drop('RESPONDIDA', axis=1).to_numpy()
    y_train = Train["RESPONDIDA"].to_numpy()
    Test = df[(df['Mes_envio']>=0.5)]
    X_test = Test.drop('RESPONDIDA', axis=1).to_numpy()
    y_test = Test["RESPONDIDA"].to_numpy()
    y_test = np_utils.to_categorical(y_test)
    y_train = np_utils.to_categorical(y_train)
    #Arquitectura del modelo
    model = Sequential()
    model.add(Dense(10, input_dim = 10, activation='relu'))
    for neuronas, funcion_activacion in capas:
      model.add(Dense(neuronas, activation = funcion_activacion))
    model.add(Dense(2, activation = 'softmax', kernel_initializer='normal'))
    model.compile(loss=f_perdida, optimizer=optimizador, metrics=['binary_accuracy'])
    # Ajuste del modelo
    callEar = EarlyStopping(monitor='loss', min_delta=0, patience=5, verbose=1)
    model.fit(X_train, y_train, epochs = epocas, batch_size = tamano, callbacks=[callEar], verbose = 1)
    scores = model.evaluate(X_test, y_test)
    precision = scores[1]
    perdida = scores[0]
    return precision, perdida, model

def red_neuronal_una_salida(df, optimizador, f_perdida, capas, epocas, tamano):
    #Particion de datos de entrenamiento y prueba
    Train = df[(df['Mes_envio']<0.5)]
    X_train = Train.drop('RESPONDIDA', axis=1).to_numpy()
    y_train = Train["RESPONDIDA"].to_numpy()
    Test = df[(df['Mes_envio']>=0.5)]
    X_test = Test.drop('RESPONDIDA', axis=1).to_numpy()
    y_test = Test["RESPONDIDA"].to_numpy()
    #Arquitectura del modelo
    model = Sequential()
    model.add(Dense(10, input_dim = 10, activation='relu'))
    for neuronas, funcion_activacion in capas:
      model.add(Dense(neuronas, activation = funcion_activacion))
    model.add(Dense(1, activation = 'relu', kernel_initializer='normal'))
    model.compile(loss=f_perdida, optimizer=optimizador, metrics=['binary_accuracy'])
    # Ajuste del modelo
    callEar = EarlyStopping(monitor='loss', min_delta=0, patience=5, verbose=1)
    model.fit(X_train, y_train, epochs = epocas, batch_size = tamano, callbacks=[callEar], verbose = 1)
    scores = model.evaluate(X_test, y_test)
    precision = scores[1]
    perdida = scores[0]
    return precision, perdida, model

# %% [markdown]
# ## Arquitecturas de una y dos salidas

# %%
# Datasets
df = pd.read_csv(path + 'Dataset_de_prueba_oficial_1.csv', sep=';')
df2 = pd.read_csv(path + 'Dataset_de_prueba_oficial_2.csv', sep=';')

# Definiciones Arquitecturas
#activation= 'sigmoid', 'relu', 'softmax', 'tanh'
#loss= 'categorical_crossentropy', 
#Optimizador = 'adams', 'sgd', 'Adagrad', 'Adamax'

#Modificar arreglo
ejecuciones = [
               #['Red9','sgd','categorical_crossentropy',[[30,'relu'],[65,'tanh'],[100, 'sigmoid'], [65,'relu'], [30,'tanh'], [10, 'sigmoid']]]
               #['Red10','adam','categorical_crossentropy',[[25,'relu'],[60,'tanh'],[90, 'sigmoid'], [60,'relu'], [30,'tanh'], [15, 'sigmoid']]],
               #['Red11','Adagrad','categorical_crossentropy',[[30,'sigmoid'],[55,'relu'],[90, 'tanh'], [65,'relu'], [35,'relu'], [10, 'sigmoid']]],
               #['Red12','sgd','categorical_crossentropy',[[25,'sigmoid'],[50,'relu'],[90, 'tanh'], [120,'relu'], [80,'relu'], [50, 'sigmoid'], [20, 'sigmoid']]],
               ['Red13','Adamax','categorical_crossentropy',[[20,'relu'],[50, 'sigmoid'],[25,'relu']]]
               #['Red14','Adamax','categorical_crossentropy',[[25,'elu'],[40, 'sigmoid'],[60,'tanh'], [35,'sigmoid'], [15,'relu']]]
               #['Red15','Adagrad','categorical_crossentropy',[[25,'sigmoid'],[50, 'elu'],[70,'relu'],[100,'tanh'], [65,'relu'], [25, 'sigmoid'], [10, 'elu']]],
               #['Red16','adam','categorical_crossentropy',[[30,'sigmoid'],[55, 'elu'],[75,'relu'],[100,'tanh'], [70,'relu'], [35, 'sigmoid'], [15, 'elu']]],
               #['Red17','sgd','categorical_crossentropy',[[25,'sigmoid'],[50, 'relu'],[75,'elu'],[100,'sigmoid'], [70,'tanh'], [35, 'relu'], [15, 'elu']]],
               #['Red18','adam','categorical_crossentropy',[[20,'elu'],[50, 'relu'],[25,'elu'],[10,'sigmoid']]],
               #['Red19','adam','categorical_crossentropy',[[25,'relu'],[45, 'softmax'],[20,'sigmoid'],[5,'sigmoid']]],
               #['Red20','sgd','categorical_crossentropy',[[20,'softmax'],[50, 'sigmoid'],[25,'tanh'],[10,'relu']]]
               ]
arr1 = []
arr2 = []
for nombre, optimizador, f_perdida, arquitectura in ejecuciones:
  redes = pd.read_excel(path + 'Diseño_arquitecturas.xlsx')
  array_capas=[]
  contador = 1
  for capa in arquitectura:
    array_capas.append([nombre, contador, capa[0], capa[1], optimizador])
    contador+=1
  nueva_Arquitectura = pd.DataFrame(array_capas,columns = ['Red', 'Capa_oculta', 'Neuronas', 'Funcion_activacion', 'Optimizador'])
  redes = pd.concat([redes, nueva_Arquitectura])
  redes.to_excel(path + 'Diseño_arquitecturas.xlsx',index = False)
  for salida in range (0, 2):
    for dataset in range (0, 2):
      for i in range (1, 6):
        # Entrenar la red
        if(dataset == 0):
          if(salida==0):
            precision, perdida, Modelo =  red_neuronal_una_salida(df, optimizador, f_perdida, arquitectura, 1000, 2200)
            arr1.append([nombre, "Dataset1", i, optimizador, f_perdida, precision, perdida])
          else:
            precision, perdida, Modelo =  red_neuronal_dos_salidas(df, optimizador, f_perdida, arquitectura, 1000, 2200)
            arr2.append([nombre, "Dataset1", i, optimizador, f_perdida, precision, perdida])
        else:
          if(salida==0):
            precision, perdida, Modelo = red_neuronal_una_salida(df2, optimizador, f_perdida, arquitectura, 1000, 1550)
            arr1.append([nombre, "Dataset2", i, optimizador, f_perdida, precision, perdida])
          else:
            precision, perdida, Modelo =  red_neuronal_dos_salidas(df, optimizador, f_perdida, arquitectura, 1000, 1550)
            arr2.append([nombre, "Dataset2", i, optimizador, f_perdida, precision, perdida])
      # Guardar el Modelo
      if(dataset == 0):
        if(salida == 0):
          Modelo.save(path + 'Modelos/'+ nombre + '_D1S1.h5')
        else:
          Modelo.save(path + 'Modelos/'+ nombre + '_D1S2.h5')
      else:
        if(salida == 0):
          Modelo.save(path + 'Modelos/'+ nombre + '_D2S1.h5')
        else:
          Modelo.save(path + 'Modelos/'+ nombre + '_D2S2.h5')

# Documentar red
df_glob1 = pd.read_excel(path + 'Datos_Red_1_salidas.xlsx')
df_salida1 = pd.DataFrame(arr1, columns = ['Red', 'Dataset', 'Iteracion', 'Optimizador', 'F_Perdida', 'Precision', 'Perdida (loss)'])
df_glob1 = pd.concat([df_glob1, df_salida1])
df_glob1.to_excel(path + 'Datos_Red_1_salidas.xlsx',index = False)

df_glob2 = pd.read_excel(path + 'Datos_Red_2_salidas.xlsx')
df_salida2 = pd.DataFrame(arr2, columns = ['Red', 'Dataset', 'Iteracion', 'Optimizador', 'F_Perdida', 'Precision', 'Perdida (loss)'])
df_glob2 = pd.concat([df_glob2, df_salida2])
df_glob2.to_excel(path + 'Datos_Red_2_salidas.xlsx', index = False)
print("Listo...")
# Out:
# Epoch 1/1000
# 996/996 [==============================] - 6s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 2/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 3/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 4/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 5/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 00005: early stopping
# 56324/56324 [==============================] - 76s 1ms/step - loss: nan - binary_accuracy: 0.9721
# Epoch 1/1000
# 996/996 [==============================] - 6s 5ms/step - loss: 3.1006e-09 - binary_accuracy: 0.9740
# Epoch 2/1000
# 996/996 [==============================] - 5s 5ms/step - loss: 3.1006e-09 - binary_accuracy: 0.9740
# Epoch 3/1000
# 996/996 [==============================] - 5s 5ms/step - loss: 3.1006e-09 - binary_accuracy: 0.9740
# Epoch 4/1000
# 996/996 [==============================] - 5s 5ms/step - loss: 3.1006e-09 - binary_accuracy: 0.9740
# Epoch 5/1000
# 996/996 [==============================] - 5s 5ms/step - loss: 3.1006e-09 - binary_accuracy: 0.9740
# Epoch 6/1000
# 996/996 [==============================] - 5s 5ms/step - loss: 3.1006e-09 - binary_accuracy: 0.9740
# Epoch 00006: early stopping
# 56324/56324 [==============================] - 75s 1ms/step - loss: 3.3202e-09 - binary_accuracy: 0.9721
# Epoch 1/1000
# 996/996 [==============================] - 6s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 2/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 3/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 4/1000
# 996/996 [==============================] - 6s 6ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 5/1000
# 996/996 [==============================] - 7s 7ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 00005: early stopping
# 56324/56324 [==============================] - 79s 1ms/step - loss: nan - binary_accuracy: 0.9721
# Epoch 1/1000
# 996/996 [==============================] - 6s 6ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 2/1000
# 996/996 [==============================] - 6s 6ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 3/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 4/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 5/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 00005: early stopping
# 56324/56324 [==============================] - 78s 1ms/step - loss: nan - binary_accuracy: 0.9721
# Epoch 1/1000
# 996/996 [==============================] - 6s 6ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 2/1000
# 996/996 [==============================] - 6s 6ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 3/1000
# 996/996 [==============================] - 5s 5ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 4/1000
# 996/996 [==============================] - 5s 6ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 5/1000
# 996/996 [==============================] - 6s 6ms/step - loss: nan - binary_accuracy: 0.9740
# Epoch 00005: early stopping
# 56324/56324 [==============================] - 79s 1ms/step - loss: nan - binary_accuracy: 0.9721
# Epoch 1/1000
# 982/982 [==============================] - 4s 4ms/step - loss: nan - binary_accuracy: 0.9626
# Epoch 2/1000
# 982/982 [==============================] - 4s 4ms/step - loss: nan - binary_accuracy: 0.9626
# Epoch 3/1000
# 982/982 [==============================] - 4s 4ms/step - loss: nan - binary_accuracy: 0.9626
# Epoch 4/1000
# 982/982 [==============================] - 4s 4ms/step - loss: nan - binary_accuracy: 0.9626
# Epoch 5/1000
# 982/982 [==============================] - 4s 4ms/step - loss: nan - binary_accuracy: 0.9626
# Epoch 00005: early stopping
# 30570/30570 [==============================] - 42s 1ms/step - loss: nan - binary_accuracy: 0.9487
# Epoch 1/1000
# 982/982 [==============================] - 5s 4ms/step - loss: 4.4635e-09 - binary_accuracy: 0.9626
# Epoch 2/1000
# 982/982 [==============================] - 4s 4ms/step - loss: 4.4635e-09 - binary_accuracy: 0.9626
# Epoch 3/1000
# 982/982 [==============================] - 4s 4ms/step - loss: 4.4635e-09 - binary_accuracy: 0.9626
# Epoch 4/1000
1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9803
# Epoch 7/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9803
# Epoch 8/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 9/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9803
# Epoch 10/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 11/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9803
# Epoch 12/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9803
# Epoch 13/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 14/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 15/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 16/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 17/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9803
# Epoch 18/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 19/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 20/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9803
# Epoch 21/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 22/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 23/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 24/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 25/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 26/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 27/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 28/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9803
# Epoch 29/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 00029: early stopping
# 56324/56324 [==============================] - 81s 1ms/step - loss: 0.0279 - binary_accuracy: 0.9814
# Epoch 1/1000
# 996/996 [==============================] - 7s 6ms/step - loss: 0.1139 - binary_accuracy: 0.9735
# Epoch 2/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0348 - binary_accuracy: 0.9800
# Epoch 3/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0339 - binary_accuracy: 0.9802
# Epoch 4/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0338 - binary_accuracy: 0.9803
# Epoch 5/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 6/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 7/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 8/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 9/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 10/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 11/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 12/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 13/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 14/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 15/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 16/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 17/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 18/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 19/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 20/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 21/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 22/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 23/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 24/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 25/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 26/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 27/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 28/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 29/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 30/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 31/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 32/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 33/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 34/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 35/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9804
# Epoch 36/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 37/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 38/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 39/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 40/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 41/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 42/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 43/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 44/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 45/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 46/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 47/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 48/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 49/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 50/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 51/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 52/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 53/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 54/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 55/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 56/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 57/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 58/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9806
# Epoch 59/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9805
# Epoch 60/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9806
# Epoch 61/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9806
# Epoch 62/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 63/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 64/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9807
# Epoch 65/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 66/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 67/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 68/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 69/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9809
# Epoch 70/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 71/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 72/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 73/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 74/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 75/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 76/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 77/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9811
# Epoch 78/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 79/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9811
# Epoch 80/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 81/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 82/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 83/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 84/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 85/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 86/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 87/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 88/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 89/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 90/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 91/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 92/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 93/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 94/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 95/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 96/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 97/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 98/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 99/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 100/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 101/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 102/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 103/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 104/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 105/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 106/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 107/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 108/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 109/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 110/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 111/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 112/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 113/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 114/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 115/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9810
# Epoch 116/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 117/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 118/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 119/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 120/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 121/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 122/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 123/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 124/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 125/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9810
# Epoch 126/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 127/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 128/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 129/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 130/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 131/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 132/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 133/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 134/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 135/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 136/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 137/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 138/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 139/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 140/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 141/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9812
# Epoch 142/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 143/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9812
# Epoch 144/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 145/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 146/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9812
# Epoch 147/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9812
# Epoch 148/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.
1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 32/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 33/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 34/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 35/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 36/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 37/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 38/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 39/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9807
# Epoch 40/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9807
# Epoch 41/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 42/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9808
# Epoch 43/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9808
# Epoch 44/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9808
# Epoch 45/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 46/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 47/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 48/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 49/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 50/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 51/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 52/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 53/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9810
# Epoch 54/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 55/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 56/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 57/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 58/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 59/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 60/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9810
# Epoch 61/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 62/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 63/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 64/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 65/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 66/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 67/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 68/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 69/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9810
# Epoch 70/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9810
# Epoch 71/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 72/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 73/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 74/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 75/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 00075: early stopping
# 56324/56324 [==============================] - 84s 1ms/step - loss: 0.0315 - binary_accuracy: 0.9872
# Epoch 1/1000
# 996/996 [==============================] - 7s 6ms/step - loss: 0.1078 - binary_accuracy: 0.9742
# Epoch 2/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0356 - binary_accuracy: 0.9791
# Epoch 3/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0341 - binary_accuracy: 0.9798
# Epoch 4/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0338 - binary_accuracy: 0.9800
# Epoch 5/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0337 - binary_accuracy: 0.9802
# Epoch 6/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0337 - binary_accuracy: 0.9802
# Epoch 7/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9803
# Epoch 8/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9803
# Epoch 9/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 10/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 11/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 12/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0336 - binary_accuracy: 0.9804
# Epoch 13/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 14/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 15/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 16/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 17/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 18/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 19/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 20/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 21/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 22/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9804
# Epoch 23/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 24/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0335 - binary_accuracy: 0.9805
# Epoch 25/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 26/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 27/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 28/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 29/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 30/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9804
# Epoch 31/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 32/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 33/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 34/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 35/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 36/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 37/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0334 - binary_accuracy: 0.9805
# Epoch 38/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 39/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 40/1000
# 996/996 [==============================] - 6s 7ms/step - loss: 0.0333 - binary_accuracy: 0.9805
# Epoch 41/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 42/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 43/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 44/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 45/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 46/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 47/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 48/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 49/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 50/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 51/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 52/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 53/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 54/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 55/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9807
# Epoch 56/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 57/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 58/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 59/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9806
# Epoch 60/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9807
# Epoch 61/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9807
# Epoch 62/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0333 - binary_accuracy: 0.9807
# Epoch 63/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 64/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 65/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 66/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 67/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 68/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 69/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 70/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 71/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 72/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 73/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 74/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 75/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9808
# Epoch 76/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9808
# Epoch 77/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 78/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9808
# Epoch 79/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9807
# Epoch 80/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0332 - binary_accuracy: 0.9808
# Epoch 81/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 82/1000
# 996/996 [==============================] - 6s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 83/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 84/1000
# 996/996 [==============================] - 6s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 85/1000
# 996/996 [==============================] - 7s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 86/1000
# 996/996 [==============================] - 7s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 87/1000
# 996/996 [==============================] - 7s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 88/1000
# 996/996 [==============================] - 7s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 89/1000
# 996/996 [==============================] - 7s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 90/1000
# 996/996 [==============================] - 7s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9808
# Epoch 91/1000
# 996/996 [==============================] - 7s 7ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 92/1000
# ...
# Epoch 75/1000
# 1413/1413 [==============================] - 8s 5ms/step - loss: 0.0331 - binary_accuracy: 0.9810
# Epoch 76/1000
# 1413/1413 [==============================] - 7s 5ms/step - loss: 0.0331 - binary_accuracy: 0.9810
# Epoch 77/1000
# 1413/1413 [==============================] - 8s 5ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 78/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 79/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0331 - binary_accuracy: 0.9809
# Epoch 80/1000
# 1413/1413 [==============================] - 8s 5ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 81/1000
# 1413/1413 [==============================] - 8s 5ms/step - loss: 0.0330 - binary_accuracy: 0.9809
# Epoch 82/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 83/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 84/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 85/1000
# 1413/1413 [==============================] - 7s 5ms/step - loss: 0.0330 - binary_accuracy: 0.9810
# Epoch 86/1000
# Epoch 105/1000
# 1413/1413 [==============================] - 8s 5ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 106/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 107/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 108/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0329 - binary_accuracy: 0.9811
# Epoch 109/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9810
# Epoch 110/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 111/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 112/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9810
# Epoch 113/1000
# 1413/1413 [==============================] - 8s 5ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 114/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 115/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 116/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 117/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 118/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 119/1000
# 1413/1413 [==============================] - 9s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 120/1000
# 1413/1413 [==============================] - 8s 5ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 121/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 122/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 123/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 124/1000
# 1413/1413 [==============================] - 9s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 125/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 126/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 127/1000
# 1413/1413 [==============================] - 8s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9811
# Epoch 00127: early stopping
# 56324/56324 [==============================] - 101s 2ms/step - loss: 0.0365 - binary_accuracy: 0.9760

# %% [markdown]
# ##Arquitectura de dos salidas

# %%
# Datasets
df = pd.read_csv(path + 'Dataset_de_prueba_oficial_1.csv', sep=';')
df2 = pd.read_csv(path + 'Dataset_de_prueba_oficial_2.csv', sep=';')

# Definiciones Arquitecturas
#activation= 'sigmoid', 'relu', 'softmax', 'tanh'
#loss= 'categorical_crossentropy', 
#Optimizador = 'adams', 'sgd'

#Modificar arreglo
ejecuciones = [
               #['Red9','sgd','categorical_crossentropy',[[30,'relu'],[65,'tanh'],[100, 'sigmoid'], [65,'relu'], [30,'tanh'], [10, 'sigmoid']]]
               #['Red10','adam','categorical_crossentropy',[[25,'relu'],[60,'tanh'],[90, 'sigmoid'], [60,'relu'], [30,'tanh'], [15, 'sigmoid']]],
               #['Red11','Adagrad','categorical_crossentropy',[[30,'sigmoid'],[55,'relu'],[90, 'tanh'], [65,'relu'], [35,'relu'], [10, 'sigmoid']]],
               #['Red12','sgd','categorical_crossentropy',[[25,'sigmoid'],[50,'relu'],[90, 'tanh'], [120,'relu'], [80,'relu'], [50, 'sigmoid'], [20, 'sigmoid']]]
               #['Red13','Adamax','categorical_crossentropy',[[20,'relu'],[50, 'sigmoid'],[25,'relu']]]
               #['Red14','Adamax','categorical_crossentropy',[[25,'elu'],[40, 'sigmoid'],[60,'tanh'], [35,'sigmoid'], [15,'relu']]]
               ['Red15','Adagrad','categorical_crossentropy',[[25,'sigmoid'],[50, 'elu'],[70,'relu'],[100,'tanh'], [65,'relu'], [25, 'sigmoid'], [10, 'elu']]]
               #['Red16','adam','categorical_crossentropy',[[30,'sigmoid'],[55, 'elu'],[75,'relu'],[100,'tanh'], [70,'relu'], [35, 'sigmoid'], [15, 'elu']]],
               #['Red17','sgd','categorical_crossentropy',[[25,'sigmoid'],[50, 'relu'],[75,'elu'],[100,'sigmoid'], [70,'tanh'], [35, 'relu'], [15, 'elu']]]
               #['Red18','adam','categorical_crossentropy',[[20,'elu'],[50, 'relu'],[25,'elu'],[10,'sigmoid']]],
               #['Red19','adam','categorical_crossentropy',[[25,'relu'],[45, 'softmax'],[20,'sigmoid'],[5,'sigmoid']]],
               #['Red20','sgd','categorical_crossentropy',[[20,'softmax'],[50, 'sigmoid'],[25,'tanh'],[10,'relu']]]
               ]
arr = []
for nombre, optimizador, f_perdida, arquitectura in ejecuciones:
  
    for dataset in range (0, 2):
      for i in range (1, 6):
        # Entrenar la red
        if(dataset == 0):
          precision, perdida, Modelo =  red_neuronal_dos_salidas(df, optimizador, f_perdida, arquitectura, 10, 4200) # Modificar funcion
          arr.append([nombre, "Dataset1", i, optimizador, f_perdida, precision, perdida])
        else:
          precision, perdida, Modelo = red_neuronal_dos_salidas(df2, optimizador, f_perdida, arquitectura, 10, 3550) # Modificar funcion
          arr.append([nombre, "Dataset2", i, optimizador, f_perdida, precision, perdida])
      if(dataset == 0):
        # Guardar el Modelo
        Modelo.save(path + 'Modelos/'+ nombre + '_D1S2.h5')
      else:
        # Guardar el Modelo
        Modelo.save(path + 'Modelos/'+ nombre + '_D2S2.h5')
# Documentar red)
df_glob = pd.read_excel(path + 'Datos_Red_2_salidas.xlsx')
df_salida = pd.DataFrame(arr,columns = ['Red', 'Dataset', 'Iteracion', 'Optimizador', 'F_Perdida', 'Precision', 'Perdida (loss)'])
df_glob = pd.concat([df_glob, df_salida])
df_glob.to_excel(path + 'Datos_Red_2_salidas.xlsx', index = False)
print("Listo...")
